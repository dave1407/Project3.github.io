# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# # Get csv data

# %%
data_age = "2018_states_by_age.csv"
age_df = pd.read_csv(data_age)
age_df.head()
# Out:
#   state       age  total_population  total_citizen_population  \
# 0    US     Total            249748                    228832
# 1    US  18 to 24             28993                     26950
# 2    US  25 to 34             44769                     39280
# 3    US  35 to 44             40784                     35403
# 4    US  45 to 64             83277                     77085
#
#    total_registered percent_registered_total margin_of_error  \
# 0            153066                     61.3             0.3
# 1             13241                     45.7             0.9
# 2             23342                     52.1             0.7
# 3             23383                     57.3             0.8
# 4             55032                     66.1             0.5
#
#   percent_registered_citizen margin_of_error_2  total_voted  \
# 0                       66.9               0.3       122281
# 1                       49.1               0.9         8726
# ...

# %%
data_sex = "2018_states_by_sex_race_hispanic_origin.csv"
sex_df = pd.read_csv(data_sex)
sex_df.head(100)
# Out:
#                    state   sex_race_and_hispanic_origin  total_population  \
# 0                     US                          Total            249748
# 1                     US                           Male            120573
# 2                     US                         Female            129176
# 3                     US                    White alone            194127
# 4                     US       White non-Hispanic alone            157610
# ..                   ...                            ...               ...
# 95              DELAWARE         Hispanic (of any race)                73
# 96              DELAWARE  White alone or in combination               548
# 97              DELAWARE  Black alone or in combination               173
# 98              DELAWARE  Asian alone or in combination                43
# 99  DISTRICT OF COLUMBIA                          Total               567
#
#     total_citizen_population  total_registered percent_registered_total  \
# ...

# %%
#if we need to merge the files here is the code, but we don't think we need it at this time
full_data = pd.concat([data_age,data_sex], axis=1)

full_data = pd.concat(
    map(pd.read_csv, [data_age,data_sex]), ignore_index=True)
#full_data.head()
#full_data.to_csv("full_data.csv")

# %% [markdown]
# ### Push data to postgresql

# %%
engine = create_engine(f'postgresql://postgres:Nico100%@localhost:5432/vote_data')

# Save the data from dataframe to
# postgres table "iris_dataset"
age_df.to_sql(
    'age_dataset', 
    engine,
    index=False # Not copying over the index
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17852\1283245590.py in <module>
#       6     'age_dataset',
#       7     engine,
# ----> 8     index=False # Not copying over the index
#       9 )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ...

# %%
engine = create_engine(f'postgresql://postgres:Nico100%@localhost:5432/vote_data')

# Save the data from dataframe to
# postgres table "iris_dataset"
sex_df.to_sql(
    'sex_dataset', 
    engine,
    index=False # Not copying over the index
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17852\3478499461.py in <module>
#       6     'sex_dataset',
#       7     engine,
# ----> 8     index=False # Not copying over the index
#       9 )
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ...

# %%
protocol = 'postgresql'
username = 'postgres'
password = 'Nico100%'
host = 'localhost'
port = 5432
database_name = 'vote_data'
rds_connection_string = f'{protocol}://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(rds_connection_string)

# %%
engine.table_names()
# Out:
# ['age_dataset', 'sex_dataset']
